# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 999)

# %%
name_basics = pd.read_csv('~/Desktop/IMDB/name.basics.tsv', delimiter = '\t')
title_akas = pd.read_csv('~/Desktop/IMDB/title.akas.tsv', delimiter = '\t')
title_basics = pd.read_csv('~/Desktop/IMDB/title.basics.tsv', delimiter = '\t')
title_crew = pd.read_csv('~/Desktop/IMDB/title.crew.tsv', delimiter = '\t')
title_principals = pd.read_csv('~/Desktop/IMDB/title.principals.tsv', delimiter = '\t')
title_ratings = pd.read_csv('~/Desktop/IMDB/title.ratings.tsv', delimiter = '\t')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # IMDB Name Basics

# %%
name_basics.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0072308,tt0050419,tt0031983,tt0053137
# 1  tt0071877,tt0117057,tt0037382,tt0038355
# 2  tt0057345,tt0054452,tt0049189,tt0056404
# 3  tt0072562,tt0080455,tt0078723,tt0077975
# 4  tt0050976,tt0050986,tt0060827,tt0069467

# %%
name_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10916797 entries, 0 to 10916796
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 499.7+ MB

# %%
name_basics.isna().sum()
# Out:
# nconst                     0
# primaryName                0
# birthYear                  0
# deathYear                  0
# primaryProfession    2313960
# knownForTitles             0
# dtype: int64

# %%
name_basics.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Removing the deceased

# %%
name_basics = name_basics[(name_basics['deathYear'] == '\\N')]

# %%
name_basics
# Out:
#              nconst         primaryName birthYear deathYear  \
# 2         nm0000003     Brigitte Bardot      1934        \N
# 46        nm0000047        Sophia Loren      1934        \N
# 78        nm0000079        Raquel Welch      1940        \N
# 82        nm0000083         Alan Miller        \N        \N
# 83        nm0000084             Gong Li      1965        \N
# ...             ...                 ...       ...       ...
# 10916792  nm9993714   Romeo del Rosario        \N        \N
# 10916793  nm9993716       Essias Loberg        \N        \N
# 10916794  nm9993717  Harikrishnan Rajan        \N        \N
# 10916795  nm9993718         Aayush Nair        \N        \N
# 10916796  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 2         actress,soundtrack,music_department
# 46                         actress,soundtrack
# 78                actress,soundtrack,producer
# 82                     editor,writer,director
# 83                                    actress
# ...                                       ...
# 10916792  animation_department,art_department
# 10916793                                  NaN
# 10916794                      cinematographer
# 10916795                      cinematographer
# 10916796                                  NaN
#
#                                    knownForTitles
# 2         tt0057345,tt0054452,tt0049189,tt0056404
# 46        tt0076085,tt0060121,tt0058335,tt0054749
# 78        tt0072281,tt0066115,tt0070291,tt0062708
# 82        tt5969604,tt0969216,tt0424773,tt0320978
# 83        tt0101640,tt0397535,tt0430357,tt0473444
# ...                                           ...
# 10916792                                tt2455546
# 10916793                                       \N
# 10916794                                tt8736744
# 10916795                                       \N
# 10916796                                       \N
#
# [10727873 rows x 6 columns]

# %%
name_basics.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # IMDB Title AKAS

# %%
title_akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 26218077  tt9916852         4                エピソード #3.20     JP       ja
# 26218078  tt9916852         5             Episódio #3.20     PT       pt
# 26218079  tt9916852         6             Episodio #3.20     IT       it
# 26218080  tt9916852         7               एपिसोड #3.20     IN       hi
# 26218081  tt9916856         1                   The Wind     DE       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 26218077           \N             \N               0
# 26218078           \N             \N               0
# 26218079           \N             \N               0
# 26218080           \N             \N               0
# 26218081           \N             \N               0
#
# [26218082 rows x 8 columns]

# %%
title_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26218082 entries, 0 to 26218081
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 1.6+ GB

# %%
title_akas.isna().sum()
# Out:
# titleId             0
# ordering            0
# title               3
# region             99
# language            0
# types               0
# attributes          0
# isOriginalTitle     0
# dtype: int64

# %% [markdown]
# # Renaming first column to match for merge

# %%
title_akas.rename(columns = {'titleId':'tconst'},inplace=True)

# %%
title_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26218082 entries, 0 to 26218081
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   tconst           object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 1.6+ GB

# %%
title_akas.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # IMDB Title Basics

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7887449 entries, 0 to 7887448
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 541.6+ MB

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle       9
# originalTitle      9
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
title_basics.duplicated().sum()
# Out:
# 0

# %%
title_basics = title_basics[(title_basics['startYear'] > 2010)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-6c20bb5f1b47> in <module>
# ----> 1 title_basics = title_basics[(title_basics['startYear'] > 2010)]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
title_basics.isna().sum()
# Out:
# tconst                0
# primary_title         0
# original_title       21
# start_year            0
# runtime_minutes       0
# genres             5408
# dtype: int64

# %% [markdown]
# # IMDB Title Crew

# %%
title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
title_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
title_crew.isna().sum()
# Out:
# tconst           0
# directors     5727
# writers      35883
# dtype: int64

# %%
title_crew.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # IMDB Title Principals

# %%
title_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
title_principals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
title_principals.isna().sum()
# Out:
# tconst             0
# ordering           0
# nconst             0
# category           0
# job           850502
# characters    634826
# dtype: int64

# %%
title_principals.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # IMDB Title Ratings

# %%
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
title_ratings.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
title_ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Merging all tables

# %%
name_principals = pd.merge(name_basics, title_principals, on='nconst')
name_principals
# Out:
#             nconst         primary_name  birth_year  death_year  \
# 0        nm0061671    Mary Ellen Bauder         NaN         NaN
# 1        nm0061865         Joseph Bauer         NaN         NaN
# 2        nm0061865         Joseph Bauer         NaN         NaN
# 3        nm0061865         Joseph Bauer         NaN         NaN
# 4        nm0061865         Joseph Bauer         NaN         NaN
# ...            ...                  ...         ...         ...
# 1016064  nm9990381         Susan Grobes         NaN         NaN
# 1016065  nm9990690          Joo Yeon So         NaN         NaN
# 1016066  nm9991320       Madeline Smith         NaN         NaN
# 1016067  nm9991786  Michelle Modigliani         NaN         NaN
# 1016068  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2        composer,music_department,sound_department
# 3        composer,music_department,sound_department
# 4        composer,music_department,sound_department
# ...                                             ...
# 1016064                                     actress
# 1016065                                     actress
# 1016066                                     actress
# 1016067                                    producer
# 1016068                       director,actor,writer
#
#                                 known_for_titles  directors    writers  \
# 0        tt0837562,tt2398241,tt0844471,tt0118553  nm0061671  nm0061671
# 1        tt0896534,tt6791238,tt0287072,tt1682940  nm0061865  nm0061865
# 2        tt0896534,tt6791238,tt0287072,tt1682940  nm0061865  nm0061865
# 3        tt0896534,tt6791238,tt0287072,tt1682940  nm0061865  nm0061865
# 4        tt0896534,tt6791238,tt0287072,tt1682940  nm0061865  nm0061865
# ...                                          ...        ...        ...
# 1016064                                      NaN  nm9990381  nm9990381
# 1016065                      tt9090932,tt8737130  nm9990690  nm9990690
# 1016066                      tt8734436,tt9615610  nm9991320  nm9991320
# 1016067                                      NaN  nm9991786  nm9991786
# 1016068                                tt8743182  nm9993380  nm9993380
#
#             tconst  ordering  category       job          characters
# 0        tt2398241         9  producer  producer                 NaN
# 1        tt0433397         7  composer       NaN                 NaN
# 2        tt1681372         8  composer       NaN                 NaN
# 3        tt2387710         8  composer       NaN                 NaN
# 4        tt2281215         7  composer       NaN                 NaN
# ...            ...       ...       ...       ...                 ...
# 1016064  tt6527982         2   actress       NaN  ["Cheryl","Gypsy"]
# 1016065  tt8737130         4   actress       NaN                 NaN
# 1016066  tt8734436         3   actress       NaN            ["Anna"]
# 1016067  tt8739240         9  producer  producer                 NaN
# 1016068  tt8743182         5  director       NaN                 NaN
#
# [1016069 rows x 13 columns]

# %%
name_principals_ratings = pd.merge(name_principals, title_ratings, on='tconst')
name_principals_ratings
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0038432         Kelly Asbury      1960.0         NaN
# 2       nm0449549        Jordan Kerner         NaN         NaN
# 3       nm0962596         Pamela Ribon      1975.0         NaN
# 4       nm0542133      Joe Manganiello      1976.0         NaN
# ...           ...                  ...         ...         ...
# 621361  nm8482246      Marco Niemeijer         NaN         NaN
# 621362  nm6870672           Sandy Ding         NaN         NaN
# 621363  nm6930231         Park Bum-Soo         NaN         NaN
# 621364  nm8481580  Aleksey Bystritskiy         NaN         NaN
# 621365  nm9400095          Jiyoung Yoo         NaN         NaN
#
#                                   primary_profession  \
# 0          miscellaneous,production_manager,producer
# 1       art_department,animation_department,director
# 2                           producer,actor,executive
# 3                            writer,producer,actress
# 4                              actor,stunts,producer
# ...                                              ...
# 621361               director,writer,cinematographer
# 621362                      director,writer,producer
# 621363                               director,writer
# 621364                                      director
# 621365                                      director
#
#                                known_for_titles  directors    writers  \
# 0       tt0837562,tt2398241,tt0844471,tt0118553  nm0061671  nm0061671
# 1       tt0298148,tt0101414,tt0166813,tt0377981  nm0038432  nm0038432
# 2       tt0101921,tt0141369,tt0119190,tt0108333  nm0449549  nm0449549
# 3       tt0898332,tt3521164,tt5848272,tt2458776  nm0962596  nm0962596
# 4       tt0974015,tt2268016,tt0844441,tt0837156  nm0542133  nm0542133
# ...                                         ...        ...        ...
# 621361                      tt7708926,tt5132170  nm8482246  nm8482246
# 621362            tt6441144,tt4150214,tt5918088  nm6870672  nm6870672
# 621363                      tt4219354,tt4773564  nm6930231  nm6930231
# 621364                      tt6112166,tt7424890  nm8481580  nm8481580
# 621365                                tt7604572  nm9400095  nm9400095
#
#            tconst  ordering  category         job       characters  \
# 0       tt2398241         9  producer    producer              NaN
# 1       tt2398241         5  director         NaN              NaN
# 2       tt2398241        10  producer    producer              NaN
# 3       tt2398241         7    writer  written by              NaN
# 4       tt2398241         3     actor         NaN  ["Hefty Smurf"]
# ...           ...       ...       ...         ...              ...
# 621361  tt7708926         1  director         NaN              NaN
# 621362  tt5918088         1  director         NaN              NaN
# 621363  tt4773564         1  director         NaN              NaN
# 621364  tt6112166         1  director         NaN              NaN
# 621365  tt7604572         1  director         NaN              NaN
#
#         averagerating  numvotes
# 0                 6.0     15612
# 1                 6.0     15612
# 2                 6.0     15612
# 3                 6.0     15612
# 4                 6.0     15612
# ...               ...       ...
# 621361            7.0         9
# 621362            7.5        20
# 621363            5.6         7
# 621364            4.8         5
# 621365            7.3         6
#
# [621366 rows x 15 columns]

# %%
name_principals_ratings_crew = pd.merge(title_crew, name_principals_ratings, on='tconst')
name_principals_ratings_crew
# Out:
#            tconst directors_x  writers_x     nconst              primary_name  \
# 0       tt0285252   nm0899854  nm0899854  nm0120025               Kim Bullard
# 1       tt0285252   nm0899854  nm0899854  nm0000686        Christopher Walken
# 2       tt0285252   nm0899854  nm0899854  nm0899854               Tony Vitale
# 3       tt0285252   nm0899854  nm0899854  nm0001822             Robert Wagner
# 4       tt0285252   nm0899854  nm0899854  nm0009272  Richard Gilbert Abramson
# ...           ...         ...        ...        ...                       ...
# 621361  tt9004986   nm4993825  nm4993825  nm1145570           John Erik Kaada
# 621362  tt9004986   nm4993825  nm4993825  nm4993825     Fredrik Horn Akselsen
# 621363  tt9004986   nm4993825  nm4993825  nm6197807          Torstein Nodland
# 621364  tt9004986   nm4993825  nm4993825  nm6450115         Thomas Kjær Olsen
# 621365  tt9004986   nm4993825  nm4993825  nm9008590               Eirin Gjørv
#
#         birth_year  death_year                    primary_profession  \
# 0              NaN         NaN  composer,soundtrack,music_department
# 1           1943.0         NaN        actor,soundtrack,miscellaneous
# 2           1964.0         NaN              producer,director,writer
# 3           1930.0         NaN             actor,producer,soundtrack
# 4              NaN         NaN                     producer,director
# ...            ...         ...                                   ...
# 621361      1975.0         NaN  composer,music_department,soundtrack
# 621362         NaN         NaN    director,writer,assistant_director
# 621363         NaN         NaN     cinematographer,camera_department
# 621364         NaN         NaN                                 actor
# 621365         NaN         NaN                              producer
#
#                                known_for_titles directors_y  writers_y  \
# 0       tt0147800,tt0117865,tt0372588,tt8889506   nm0120025  nm0120025
# 1       tt0077416,tt0264464,tt1931533,tt0427327   nm0000686  nm0000686
# 2       tt0285252,tt0106489,tt0119465,tt0359774   nm0899854  nm0899854
# 3       tt0072308,tt0118655,tt0295178,tt0106770   nm0001822  nm0001822
# 4       tt0096926,tt0114658,tt0090500,tt0089791   nm0009272  nm0009272
# ...                                         ...         ...        ...
# 621361  tt3202392,tt3650484,tt3346824,tt1153110   nm1145570  nm1145570
# 621362  tt2368989,tt9737848,tt9004986,tt4517204   nm4993825  nm4993825
# 621363  tt9004986,tt8571630,tt3447810,tt9737848   nm6197807  nm6197807
# 621364                                tt3688926   nm6450115  nm6450115
# 621365            tt9174792,tt6915890,tt9004986   nm9008590  nm9008590
#
#         ordering         category       job             characters  \
# 0              9         composer       NaN                    NaN
# 1              3            actor       NaN       ["Roy Callahan"]
# 2              5         director       NaN                    NaN
# 3              4            actor       NaN           ["Tom Wald"]
# 4              6         producer  producer                    NaN
# ...          ...              ...       ...                    ...
# 621361         7         composer       NaN                    NaN
# 621362         5         director       NaN                    NaN
# 621363         9  cinematographer       NaN                    NaN
# 621364         3            actor       NaN  ["Young Mads Ousdal"]
# 621365         6         producer  producer                    NaN
#
#         averagerating  numvotes
# 0                 3.9       219
# 1                 3.9       219
# 2                 3.9       219
# 3                 3.9       219
# 4                 3.9       219
# ...               ...       ...
# 621361            8.4         7
# 621362            8.4         7
# 621363            8.4         7
# 621364            8.4         7
# 621365            8.4         7
#
# [621366 rows x 17 columns]

# %%
name_principals_ratings_crew_basics = pd.merge(title_basics, name_principals_ratings_crew, on='tconst')
name_principals_ratings_crew_basics
# Out:
#            tconst                    primary_title   original_title  \
# 0       tt0063540                        Sunghursh        Sunghursh
# 1       tt0063540                        Sunghursh        Sunghursh
# 2       tt0063540                        Sunghursh        Sunghursh
# 3       tt0063540                        Sunghursh        Sunghursh
# 4       tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din
# ...           ...                              ...              ...
# 621361  tt9916160                       Drømmeland       Drømmeland
# 621362  tt9916160                       Drømmeland       Drømmeland
# 621363  tt9916160                       Drømmeland       Drømmeland
# 621364  tt9916160                       Drømmeland       Drømmeland
# 621365  tt9916160                       Drømmeland       Drømmeland
#
#         start_year  runtime_minutes              genres directors_x  \
# 0             2013            175.0  Action,Crime,Drama   nm0712540
# 1             2013            175.0  Action,Crime,Drama   nm0712540
# 2             2013            175.0  Action,Crime,Drama   nm0712540
# 3             2013            175.0  Action,Crime,Drama   nm0712540
# 4             2019            114.0     Biography,Drama   nm0002411
# ...            ...              ...                 ...         ...
# 621361        2019             72.0         Documentary   nm5684093
# 621362        2019             72.0         Documentary   nm5684093
# 621363        2019             72.0         Documentary   nm5684093
# 621364        2019             72.0         Documentary   nm5684093
# 621365        2019             72.0         Documentary   nm5684093
#
#                                       writers_x     nconst  \
# 0       nm0023551,nm1194313,nm0347899,nm1391276  nm0347899
# 1       nm0023551,nm1194313,nm0347899,nm1391276  nm0904537
# 2       nm0023551,nm1194313,nm0347899,nm1391276  nm0474801
# 3       nm0023551,nm1194313,nm0347899,nm1391276  nm1391276
# 4                                           NaN  nm0451809
# ...                                         ...        ...
# 621361                                      NaN  nm4241788
# 621362                                      NaN  nm3256778
# 621363                                      NaN  nm6969694
# 621364                                      NaN  nm6460816
# 621365                                      NaN  nm5684093
#
#               primary_name  birth_year  death_year  \
# 0                   Gulzar      1936.0         NaN
# 1           Vyjayanthimala      1933.0         NaN
# 2              Dilip Kumar      1922.0         NaN
# 3            Anjana Rawail         NaN         NaN
# 4             Arun Khopkar      1945.0         NaN
# ...                    ...         ...         ...
# 621361      Tobias Borkert         NaN         NaN
# 621362       Tom Denoyette         NaN         NaN
# 621363   Rogier Timmermans         NaN         NaN
# 621364         Nils Leidal         NaN         NaN
# 621365  Joost van der Wiel         NaN         NaN
#
#                             primary_profession  \
# 0           music_department,writer,soundtrack
# 1       actress,music_department,miscellaneous
# 2                        actor,writer,director
# 3                      writer,costume_designer
# 4            director,actor,assistant_director
# ...                                        ...
# 621361               composer,music_department
# 621362             editor,editorial_department
# 621363       cinematographer,camera_department
# 621364                                     NaN
# 621365         director,cinematographer,writer
#
#                                known_for_titles directors_y  writers_y  \
# 0       tt0091256,tt0178186,tt1010048,tt2176013   nm0347899  nm0347899
# 1       tt0047990,tt0054910,tt0050665,tt0058547   nm0904537  nm0904537
# 2       tt0058287,tt0054910,tt0047990,tt0084667   nm0474801  nm0474801
# 3       tt0293499,tt0266712,tt0266757,tt0063540   nm1391276  nm1391276
# 4       tt0231382,tt0231583,tt0232192,tt3693912   nm0451809  nm0451809
# ...                                         ...         ...        ...
# 621361  tt8129666,tt6264034,tt1641810,tt4653186   nm4241788  nm4241788
# 621362  tt1625150,tt7431570,tt5492502,tt2878178   nm3256778  nm3256778
# 621363                      tt4160582,tt7941300   nm6969694  nm6969694
# 621364                                tt3698384   nm6460816  nm6460816
# 621365                      tt2927550,tt4000564   nm5684093  nm5684093
#
#         ordering         category         job  \
# 0              8           writer    dialogue
# 1              2          actress         NaN
# 2              1            actor         NaN
# 3              9           writer  screenplay
# 4              2            actor         NaN
# ...          ...              ...         ...
# 621361         4         composer         NaN
# 621362         6           editor         NaN
# 621363         5  cinematographer         NaN
# 621364         1             self         NaN
# 621365         2         director         NaN
#
#                              characters  averagerating  numvotes
# 0                                   NaN            7.0        77
# 1           ["Munni","Laila-E-Aasmaan"]            7.0        77
# 2       ["Kundan S. Prasad","Bajrangi"]            7.0        77
# 3                                   NaN            7.0        77
# 4                          ["Kalidasa"]            7.2        43
# ...                                 ...            ...       ...
# 621361                              NaN            6.5        11
# 621362                              NaN            6.5        11
# 621363                              NaN            6.5        11
# 621364                      ["Himself"]            6.5        11
# 621365                              NaN            6.5        11
#
# [621366 rows x 22 columns]

# %% [markdown]
# # Final Table Merge

# %%
pd.set_option('display.max_columns', 500)

# %%
final_merge = pd.merge(title_akas, name_principals_ratings_crew_basics, on='tconst')
final_merge
# Out:
#             tconst  ordering_x          title region language        types  \
# 0        tt0369610          10  Джурасик свят     BG       bg          NaN
# 1        tt0369610          10  Джурасик свят     BG       bg          NaN
# 2        tt0369610          10  Джурасик свят     BG       bg          NaN
# 3        tt0369610          10  Джурасик свят     BG       bg          NaN
# 4        tt0369610          10  Джурасик свят     BG       bg          NaN
# ...            ...         ...            ...    ...      ...          ...
# 2380443  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380444  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380445  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380446  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380447  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
#
#         attributes  is_original_title   primary_title      original_title  \
# 0              NaN                0.0  Jurassic World      Jurassic World
# 1              NaN                0.0  Jurassic World      Jurassic World
# 2              NaN                0.0  Jurassic World      Jurassic World
# 3              NaN                0.0  Jurassic World      Jurassic World
# 4              NaN                0.0  Jurassic World      Jurassic World
# ...            ...                ...             ...                 ...
# 2380443        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380444        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380445        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380446        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380447        NaN                0.0   Farewell Song  Sayonara kuchibiru
#
#          start_year  runtime_minutes                   genres directors_x  \
# 0              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 1              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 2              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 3              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 4              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# ...             ...              ...                      ...         ...
# 2380443        2019            116.0            Music,Romance   nm0794048
# 2380444        2019            116.0            Music,Romance   nm0794048
# 2380445        2019            116.0            Music,Romance   nm0794048
# 2380446        2019            116.0            Music,Romance   nm0794048
# 2380447        2019            116.0            Music,Romance   nm0794048
#
#                                                  writers_x     nconst  \
# 0        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0339460
# 1        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0695435
# 2        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0397171
# 3        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0798646
# 4        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm1119880
# ...                                                    ...        ...
# 2380443                                          nm0794048  nm5282266
# 2380444                                          nm0794048  nm5862455
# 2380445                                          nm0794048  nm4869921
# 2380446                                          nm0794048  nm6954008
# 2380447                                          nm0794048  nm5527231
#
#                 primary_name  birth_year  death_year  \
# 0                 Judy Greer      1975.0         NaN
# 1                Chris Pratt      1979.0         NaN
# 2        Bryce Dallas Howard      1981.0         NaN
# 3              Amanda Silver      1963.0         NaN
# 4            Colin Trevorrow      1976.0         NaN
# ...                      ...         ...         ...
# 2380443        Mugi Kadowaki         NaN         NaN
# 2380444         Nana Komatsu         NaN         NaN
# 2380445         Masaki Naito      1981.0         NaN
# 2380446           Ryô Narita         NaN         NaN
# 2380447        Takaya Aoyagi      1985.0         NaN
#
#                   primary_profession  \
# 0        actress,producer,soundtrack
# 1          actor,soundtrack,producer
# 2            actress,director,writer
# 3            writer,producer,actress
# 4           writer,producer,director
# ...                              ...
# 2380443                      actress
# 2380444           actress,soundtrack
# 2380445                        actor
# 2380446                        actor
# 2380447                        actor
#
#                                  known_for_titles directors_y  writers_y  \
# 0         tt0369610,tt0337563,tt0478970,tt0988595   nm0339460  nm0339460
# 1         tt1490017,tt0369610,tt1266020,tt2015381   nm0695435  nm0695435
# 2                   tt1454029,tt0369610,tt1800302   nm0397171  nm0397171
# 3         tt2103281,tt1318514,tt0369610,tt3450958   nm0798646  nm0798646
# 4         tt0369610,tt4881806,tt4572792,tt1862079   nm1119880  nm1119880
# ...                                           ...         ...        ...
# 2380443   tt3108170,tt4651928,tt9827784,tt8764582   nm5282266  nm5282266
# 2380444   tt4912452,tt0490215,tt5108912,tt3108158   nm5862455  nm5862455
# 2380445   tt7268368,tt2267524,tt9827784,tt3502172   nm4869921  nm4869921
# 2380446  tt10127410,tt5311514,tt5031744,tt8531044   nm6954008  nm6954008
# 2380447   tt7772394,tt6344334,tt6344302,tt5678870   nm5527231  nm5527231
#
#          ordering_y  category            job  characters  averagerating  \
# 0                 4   actress            NaN   ["Karen"]            7.0
# 1                 1     actor            NaN    ["Owen"]            7.0
# 2                 2   actress            NaN  ["Claire"]            7.0
# 3                 7    writer  screenplay by         NaN            7.0
# 4                 5  director            NaN         NaN            7.0
# ...             ...       ...            ...         ...            ...
# 2380443           1   actress            NaN    ["Haru"]            7.7
# 2380444           2   actress            NaN     ["Reo"]            7.7
# 2380445          10     actor            NaN         NaN            7.7
# 2380446           3     actor            NaN   ["Shima"]            7.7
# 2380447           4     actor            NaN         NaN            7.7
#
#          numvotes
# 0          539338
# 1          539338
# 2          539338
# 3          539338
# 4          539338
# ...           ...
# 2380443         6
# 2380444         6
# 2380445         6
# 2380446         6
# 2380447         6
#
# [2380448 rows x 29 columns]

# %%
temp_table = final_merge
temp_table_1 = temp_table[temp_table['known_for_titles'].notna()]
temp_table_1
# Out:
#             tconst  ordering_x          title region language        types  \
# 0        tt0369610          10  Джурасик свят     BG       bg          NaN
# 1        tt0369610          10  Джурасик свят     BG       bg          NaN
# 2        tt0369610          10  Джурасик свят     BG       bg          NaN
# 3        tt0369610          10  Джурасик свят     BG       bg          NaN
# 4        tt0369610          10  Джурасик свят     BG       bg          NaN
# ...            ...         ...            ...    ...      ...          ...
# 2380443  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380444  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380445  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380446  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380447  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
#
#         attributes  is_original_title   primary_title      original_title  \
# 0              NaN                0.0  Jurassic World      Jurassic World
# 1              NaN                0.0  Jurassic World      Jurassic World
# 2              NaN                0.0  Jurassic World      Jurassic World
# 3              NaN                0.0  Jurassic World      Jurassic World
# 4              NaN                0.0  Jurassic World      Jurassic World
# ...            ...                ...             ...                 ...
# 2380443        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380444        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380445        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380446        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380447        NaN                0.0   Farewell Song  Sayonara kuchibiru
#
#          start_year  runtime_minutes                   genres directors_x  \
# 0              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 1              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 2              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 3              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 4              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# ...             ...              ...                      ...         ...
# 2380443        2019            116.0            Music,Romance   nm0794048
# 2380444        2019            116.0            Music,Romance   nm0794048
# 2380445        2019            116.0            Music,Romance   nm0794048
# 2380446        2019            116.0            Music,Romance   nm0794048
# 2380447        2019            116.0            Music,Romance   nm0794048
#
#                                                  writers_x     nconst  \
# 0        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0339460
# 1        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0695435
# 2        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0397171
# 3        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0798646
# 4        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm1119880
# ...                                                    ...        ...
# 2380443                                          nm0794048  nm5282266
# 2380444                                          nm0794048  nm5862455
# 2380445                                          nm0794048  nm4869921
# 2380446                                          nm0794048  nm6954008
# 2380447                                          nm0794048  nm5527231
#
#                 primary_name  birth_year           primary_profession  \
# 0                 Judy Greer      1975.0  actress,producer,soundtrack
# 1                Chris Pratt      1979.0    actor,soundtrack,producer
# 2        Bryce Dallas Howard      1981.0      actress,director,writer
# 3              Amanda Silver      1963.0      writer,producer,actress
# 4            Colin Trevorrow      1976.0     writer,producer,director
# ...                      ...         ...                          ...
# 2380443        Mugi Kadowaki         NaN                      actress
# 2380444         Nana Komatsu         NaN           actress,soundtrack
# 2380445         Masaki Naito      1981.0                        actor
# 2380446           Ryô Narita         NaN                        actor
# 2380447        Takaya Aoyagi      1985.0                        actor
#
#                                  known_for_titles  category            job  \
# 0         tt0369610,tt0337563,tt0478970,tt0988595   actress            NaN
# 1         tt1490017,tt0369610,tt1266020,tt2015381     actor            NaN
# 2                   tt1454029,tt0369610,tt1800302   actress            NaN
# 3         tt2103281,tt1318514,tt0369610,tt3450958    writer  screenplay by
# 4         tt0369610,tt4881806,tt4572792,tt1862079  director            NaN
# ...                                           ...       ...            ...
# 2380443   tt3108170,tt4651928,tt9827784,tt8764582   actress            NaN
# 2380444   tt4912452,tt0490215,tt5108912,tt3108158   actress            NaN
# 2380445   tt7268368,tt2267524,tt9827784,tt3502172     actor            NaN
# 2380446  tt10127410,tt5311514,tt5031744,tt8531044     actor            NaN
# 2380447   tt7772394,tt6344334,tt6344302,tt5678870     actor            NaN
#
#          characters  averagerating  numvotes
# 0         ["Karen"]            7.0    539338
# 1          ["Owen"]            7.0    539338
# 2        ["Claire"]            7.0    539338
# 3               NaN            7.0    539338
# 4               NaN            7.0    539338
# ...             ...            ...       ...
# 2380443    ["Haru"]            7.7         6
# 2380444     ["Reo"]            7.7         6
# 2380445         NaN            7.7         6
# 2380446   ["Shima"]            7.7         6
# 2380447         NaN            7.7         6
#
# [2365134 rows x 25 columns]

# %%
temp_table_1['split_writers'] = temp_table_1['writers_x']
temp_table_1['split_writers'] = [i.split(',') for i in temp_table_1['split_writers']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-2d2a99138cb7> in <module>
#       1 temp_table_1['split_writers'] = temp_table_1['writers_x']
# ----> 2 temp_table_1['split_writers'] = [i.split(',') for i in temp_table_1['split_writers']]
#
# <ipython-input-109-2d2a99138cb7> in <listcomp>(.0)
#       1 temp_table_1['split_writers'] = temp_table_1['writers_x']
# ----> 2 temp_table_1['split_writers'] = [i.split(',') for i in temp_table_1['split_writers']]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
z = [i.split(',') for i in temp_table_1['known_for_titles']]
temp_table_1['list_of_known'] = z
temp_table_1
# Out:
#             tconst  ordering_x          title region language        types  \
# 0        tt0369610          10  Джурасик свят     BG       bg          NaN
# 1        tt0369610          10  Джурасик свят     BG       bg          NaN
# 2        tt0369610          10  Джурасик свят     BG       bg          NaN
# 3        tt0369610          10  Джурасик свят     BG       bg          NaN
# 4        tt0369610          10  Джурасик свят     BG       bg          NaN
# ...            ...         ...            ...    ...      ...          ...
# 2380443  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380444  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380445  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380446  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
# 2380447  tt9827784           3  Farewell Song    XWW       en  imdbDisplay
#
#         attributes  is_original_title   primary_title      original_title  \
# 0              NaN                0.0  Jurassic World      Jurassic World
# 1              NaN                0.0  Jurassic World      Jurassic World
# 2              NaN                0.0  Jurassic World      Jurassic World
# 3              NaN                0.0  Jurassic World      Jurassic World
# 4              NaN                0.0  Jurassic World      Jurassic World
# ...            ...                ...             ...                 ...
# 2380443        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380444        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380445        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380446        NaN                0.0   Farewell Song  Sayonara kuchibiru
# 2380447        NaN                0.0   Farewell Song  Sayonara kuchibiru
#
#          start_year  runtime_minutes                   genres directors_x  \
# 0              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 1              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 2              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 3              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# 4              2015            124.0  Action,Adventure,Sci-Fi   nm1119880
# ...             ...              ...                      ...         ...
# 2380443        2019            116.0            Music,Romance   nm0794048
# 2380444        2019            116.0            Music,Romance   nm0794048
# 2380445        2019            116.0            Music,Romance   nm0794048
# 2380446        2019            116.0            Music,Romance   nm0794048
# 2380447        2019            116.0            Music,Romance   nm0794048
#
#                                                  writers_x     nconst  \
# 0        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0339460
# 1        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0695435
# 2        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0397171
# 3        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0798646
# 4        nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm1119880
# ...                                                    ...        ...
# 2380443                                          nm0794048  nm5282266
# 2380444                                          nm0794048  nm5862455
# 2380445                                          nm0794048  nm4869921
# 2380446                                          nm0794048  nm6954008
# 2380447                                          nm0794048  nm5527231
#
#                 primary_name  birth_year           primary_profession  \
# 0                 Judy Greer      1975.0  actress,producer,soundtrack
# 1                Chris Pratt      1979.0    actor,soundtrack,producer
# 2        Bryce Dallas Howard      1981.0      actress,director,writer
# 3              Amanda Silver      1963.0      writer,producer,actress
# 4            Colin Trevorrow      1976.0     writer,producer,director
# ...                      ...         ...                          ...
# 2380443        Mugi Kadowaki         NaN                      actress
# 2380444         Nana Komatsu         NaN           actress,soundtrack
# 2380445         Masaki Naito      1981.0                        actor
# 2380446           Ryô Narita         NaN                        actor
# 2380447        Takaya Aoyagi      1985.0                        actor
#
#                                  known_for_titles  category            job  \
# 0         tt0369610,tt0337563,tt0478970,tt0988595   actress            NaN
# 1         tt1490017,tt0369610,tt1266020,tt2015381     actor            NaN
# 2                   tt1454029,tt0369610,tt1800302   actress            NaN
# 3         tt2103281,tt1318514,tt0369610,tt3450958    writer  screenplay by
# 4         tt0369610,tt4881806,tt4572792,tt1862079  director            NaN
# ...                                           ...       ...            ...
# 2380443   tt3108170,tt4651928,tt9827784,tt8764582   actress            NaN
# 2380444   tt4912452,tt0490215,tt5108912,tt3108158   actress            NaN
# 2380445   tt7268368,tt2267524,tt9827784,tt3502172     actor            NaN
# 2380446  tt10127410,tt5311514,tt5031744,tt8531044     actor            NaN
# 2380447   tt7772394,tt6344334,tt6344302,tt5678870     actor            NaN
#
#          characters  averagerating  numvotes  \
# 0         ["Karen"]            7.0    539338
# 1          ["Owen"]            7.0    539338
# 2        ["Claire"]            7.0    539338
# 3               NaN            7.0    539338
# 4               NaN            7.0    539338
# ...             ...            ...       ...
# 2380443    ["Haru"]            7.7         6
# 2380444     ["Reo"]            7.7         6
# 2380445         NaN            7.7         6
# 2380446   ["Shima"]            7.7         6
# 2380447         NaN            7.7         6
#
#                                          list_of_known
# 0         [tt0369610, tt0337563, tt0478970, tt0988595]
# 1         [tt1490017, tt0369610, tt1266020, tt2015381]
# 2                    [tt1454029, tt0369610, tt1800302]
# 3         [tt2103281, tt1318514, tt0369610, tt3450958]
# 4         [tt0369610, tt4881806, tt4572792, tt1862079]
# ...                                                ...
# 2380443   [tt3108170, tt4651928, tt9827784, tt8764582]
# 2380444   [tt4912452, tt0490215, tt5108912, tt3108158]
# 2380445   [tt7268368, tt2267524, tt9827784, tt3502172]
# 2380446  [tt10127410, tt5311514, tt5031744, tt8531044]
# 2380447   [tt7772394, tt6344334, tt6344302, tt5678870]
#
# [2365134 rows x 26 columns]

# %%
testing = zip(title_basics['tconst'], title_basics['original_title'])
testing_1 = {t: o for t, o in testing}
testing_1['tt0369610']
# Out:
# 'Jurassic World'

# %%
writers_1 = zip()

# %%
def title_finder(list_of_tconst):
    names = []
    for tconst in list_of_tconst:
        try:
            names.append(testing_1[tconst])
        except:
            names.append('no_title')
    return names

# %%
title_finder(temp_table_1['list_of_known'][0])
# Out:
# ['Jurassic World', 'no_title', 'Ant-Man', 'no_title']

# %%
temp_table_1['the_list_of_known'] = temp_table_1['list_of_known'].apply(title_finder)

# %%
temp_table_1.head()
# Out:
#       tconst  ordering_x          title region language types attributes  \
# 0  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 1  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 2  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 3  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 4  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title   primary_title  original_title  start_year  \
# 0                0.0  Jurassic World  Jurassic World        2015
# 1                0.0  Jurassic World  Jurassic World        2015
# 2                0.0  Jurassic World  Jurassic World        2015
# 3                0.0  Jurassic World  Jurassic World        2015
# 4                0.0  Jurassic World  Jurassic World        2015
#
#    runtime_minutes                   genres directors_x  \
# 0            124.0  Action,Adventure,Sci-Fi   nm1119880
# 1            124.0  Action,Adventure,Sci-Fi   nm1119880
# 2            124.0  Action,Adventure,Sci-Fi   nm1119880
# 3            124.0  Action,Adventure,Sci-Fi   nm1119880
# 4            124.0  Action,Adventure,Sci-Fi   nm1119880
#
#                                            writers_x     nconst  \
# 0  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0339460
# 1  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0695435
# 2  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0397171
# 3  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm0798646
# 4  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341  nm1119880
#
#           primary_name  birth_year  death_year           primary_profession  \
# 0           Judy Greer      1975.0         NaN  actress,producer,soundtrack
# 1          Chris Pratt      1979.0         NaN    actor,soundtrack,producer
# 2  Bryce Dallas Howard      1981.0         NaN      actress,director,writer
# 3        Amanda Silver      1963.0         NaN      writer,producer,actress
# 4      Colin Trevorrow      1976.0         NaN     writer,producer,director
#
#                           known_for_titles directors_y  writers_y  ordering_y  \
# 0  tt0369610,tt0337563,tt0478970,tt0988595   nm0339460  nm0339460           4
# 1  tt1490017,tt0369610,tt1266020,tt2015381   nm0695435  nm0695435           1
# 2            tt1454029,tt0369610,tt1800302   nm0397171  nm0397171           2
# 3  tt2103281,tt1318514,tt0369610,tt3450958   nm0798646  nm0798646           7
# 4  tt0369610,tt4881806,tt4572792,tt1862079   nm1119880  nm1119880           5
#
#    category            job  characters  averagerating  numvotes  \
# 0   actress            NaN   ["Karen"]            7.0    539338
# 1     actor            NaN    ["Owen"]            7.0    539338
# 2   actress            NaN  ["Claire"]            7.0    539338
# 3    writer  screenplay by         NaN            7.0    539338
# 4  director            NaN         NaN            7.0    539338
#
#                                   list_of_known  \
# 0  [tt0369610, tt0337563, tt0478970, tt0988595]
# 1  [tt1490017, tt0369610, tt1266020, tt2015381]
# 2             [tt1454029, tt0369610, tt1800302]
# 3  [tt2103281, tt1318514, tt0369610, tt3450958]
# 4  [tt0369610, tt4881806, tt4572792, tt1862079]
#
#                                    the_list_of_known
# 0      [Jurassic World, no_title, Ant-Man, no_title]
# 1  [The Lego Movie, Jurassic World, no_title, Gua...
# 2                   [The Help, Jurassic World, Gold]
# 3  [Dawn of the Planet of the Apes, Rise of the P...
# 4  [Jurassic World, Jurassic World: Fallen Kingdo...

# %% [markdown]
# # Final Merge Clean Up

# %%
final_merge.drop('death_year', 1, inplace=True)
final_merge.drop('ordering_y', 1, inplace=True)
final_merge.drop('writers_y', 1, inplace=True)
final_merge.drop('directors_y', 1, inplace=True)

# %%
x = final_merge[(final_merge['is_original_title'] == 1) & (final_merge['category'] == 'director')]

# %% [markdown]
# # Top 10 Regions

# %%
top_10_regions = final_merge['region'].value_counts()[:10].index
top_10_regions
# Out:
# Index(['US', 'XWW', 'RU', 'DE', 'FR', 'PL', 'BR', 'ES', 'HU', 'IN'], dtype='object')

# %% [markdown]
# # Average Rating by Top 10 Regions

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
popular_regions = final_merge[(final_merge['region'].isin(top_10_regions)) &\
                              (final_merge['numvotes'] >= 5000)]
                
#total movies directors have appeared in 
all_regions = popular_regions['region'].value_counts()
#filtering director names that appear more than 3 times
all_regions_greater_2 = all_regions.values >= 100
#filtered names list vs geart than 3 list
the_regions_name = all_regions[all_regions_greater_2]

x = final_merge[(final_merge['region'].isin(the_regions_name.index))]
top_10_regions = x.groupby('region')['averagerating'].mean().sort_values(ascending = False)
top_10_regions
# Out:
# Series([], Name: averagerating, dtype: float64)

# %% [markdown]
# # Top 10 Genres by Top 10 Regions

# %%
final_merge['title'].unique()
# Out:
# array(['Джурасик свят', 'Jurashikku warudo',
#        'Jurassic World: O Mundo dos Dinossauros', ...,
#        'Qi Tian Da Sheng Huo Yan Shan', 'Sayonara kuchibiru',
#        'Farewell Song'], dtype=object)

# %%
list_of_genres = final_merge['genres'].value_counts()[:50]
#all directors appearing in original title movies with a total number of votes greater than 5000
all_genres = final_merge[(final_merge['genres'].isin(list_of_genres.index)) &\
                            (final_merge['region'].isin(top_10_regions.index))&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_genres = all_genres['genres'].value_counts()
#filtering director names that appear more than 3 times
all_genres_greater_2 = all_genres.values >= 100
#filtered names list vs geart than 3 list
the_genres_name = all_genres[all_genres_greater_2]

x = final_merge[(final_merge['genres'].isin(the_genres_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
top_10_genres_regions = x.groupby('genres')['averagerating'].mean().sort_values(ascending = False)
x
# Out:
# Empty DataFrame
# Columns: [tconst, ordering_x, title, language, types, attributes, is_original_title, primary_title, original_title, start_year, runtime_minutes, genres, directors_x, writers_x, nconst, primary_name, birth_year, death_year, primary_profession, known_for_titles, directors_y, writers_y, ordering_y, category, job, characters, averagerating, numvotes]
# Index: []

# %% [markdown]
# # Top 10 Genres

# %%
list_of_genres = final_merge['genres'].value_counts()[:50]
#all directors appearing in original title movies with a total number of votes greater than 5000
all_genres = final_merge[(final_merge['genres'].isin(list_of_genres.index)) &\
                            (final_merge['is_original_title'] == 1)&\
                           (final_merge['numvotes'] >= 33000)]
#total movies directors have appeared in 
all_genres = all_genres['genres'].value_counts()
#filtering director names that appear more than 3 times
all_genres_greater_2 = all_genres.values >= 100
#filtered names list vs geart than 3 list
the_genres_name = all_genres[all_genres_greater_2]

x = final_merge[(final_merge['genres'].isin(the_genres_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
top_10_genres = x.groupby('genres')['averagerating'].mean().sort_values(ascending = False)
y = x.drop_duplicates(subset = 'tconst')
y
# Out:
#             tconst  ordering_x  \
# 342      tt0369610          45
# 721      tt0401729           7
# 1396     tt1179034           5
# 2737     tt1235522           7
# 2801     tt1252507           1
# ...            ...         ...
# 2380097  tt9310460           4
# 2380163  tt9356320           4
# 2380241  tt9450542           2
# 2380376  tt9657946           3
# 2380402  tt9726638           2
#
#                                                      title language     types  \
# 342                                         Jurassic World      NaN  original
# 721                                            John Carter      NaN  original
# 1396                                  From Paris with Love      NaN  original
# 2737                                           Broken City      NaN  original
# 2801                                          The Way Home      NaN  original
# ...                                                    ...      ...       ...
# 2380097  Der kleine Drache Kokosnuss - Auf in den Dschu...      NaN  original
# 2380163                      Segunda estrella a la derecha      NaN  original
# 2380241                     Babushka lyogkogo povedeniya 2      NaN  original
# 2380376                                          Querência      NaN  original
# 2380402                           Monkey King: The Volcano      NaN  original
#
#         attributes  is_original_title  \
# 342            NaN                1.0
# 721            NaN                1.0
# 1396           NaN                1.0
# 2737           NaN                1.0
# 2801           NaN                1.0
# ...            ...                ...
# 2380097        NaN                1.0
# 2380163        NaN                1.0
# 2380241        NaN                1.0
# 2380376        NaN                1.0
# 2380402        NaN                1.0
#
#                                        primary_title  \
# 342                                   Jurassic World
# 721                                      John Carter
# 1396                            From Paris with Love
# 2737                                     Broken City
# 2801                                    The Way Home
# ...                                              ...
# 2380097  Coconut the Little Dragon 2 Into the Jungle
# 2380163                     Second Star on the Right
# 2380241               Babushka lyogkogo povedeniya 2
# 2380376                                       Homing
# 2380402                     Monkey King: The Volcano
#
#                                             original_title  start_year  \
# 342                                         Jurassic World        2015
# 721                                            John Carter        2012
# 1396                                  From Paris with Love        2010
# 2737                                           Broken City        2013
# 2801                                          The Way Home        2010
# ...                                                    ...         ...
# 2380097  Der kleine Drache Kokosnuss - Auf in den Dschu...        2018
# 2380163                      Segunda estrella a la derecha        2019
# 2380241                     Babushka lyogkogo povedeniya 2        2019
# 2380376                                          Querência        2019
# 2380402                           Monkey King: The Volcano        2019
#
#          runtime_minutes                      genres directors_x  \
# 342           124.000000     Action,Adventure,Sci-Fi   nm1119880
# 721           132.000000     Action,Adventure,Sci-Fi   nm0004056
# 1396           92.000000       Action,Crime,Thriller   nm0603628
# 2737          109.000000        Crime,Drama,Thriller   nm0400441
# 2801           89.000000                       Drama   nm0004165
# ...                  ...                         ...         ...
# 2380097        86.187247  Adventure,Animation,Comedy   nm2106115
# 2380163        83.000000                      Comedy   nm5168373
# 2380241        86.000000                      Comedy   nm0049592
# 2380376        90.000000                       Drama   nm2320629
# 2380402        90.000000     Action,Adventure,Comedy  nm10021724
#
#                                                  writers_x      nconst  \
# 342      nm0415425,nm0798646,nm1119880,nm2081046,nm0000341   nm0339460
# 721                nm0004056,nm0028764,nm0149290,nm0123194   nm0000353
# 1396                                   nm0367867,nm0000108   nm0367867
# 2737                                             nm3017566   nm0400441
# 2801                                             nm0004165   nm0001002
# ...                                                    ...         ...
# 2380097                                nm2173401,nm0910419   nm1110828
# 2380163                                          nm5168373  nm10162112
# 2380241                                                NaN   nm0049592
# 2380376                                          nm2320629  nm10425794
# 2380402                                                NaN   nm0874676
#
#                primary_name  birth_year  death_year  \
# 342              Judy Greer      1975.0         NaN
# 721            Willem Dafoe      1955.0         NaN
# 1396              Adi Hasak         NaN         NaN
# 2737           Allen Hughes      1972.0         NaN
# 2801              Dean Cain      1966.0         NaN
# ...                     ...         ...         ...
# 2380097  Dustin Semmelrogge      1980.0         NaN
# 2380163  Alejandro Sandoval         NaN         NaN
# 2380241    Marius Balchunas      1971.0         NaN
# 2380376    Marcelo Di Souza         NaN         NaN
# 2380402          Eric Tsang      1953.0         NaN
#
#                   primary_profession                         known_for_titles  \
# 342      actress,producer,soundtrack  tt0369610,tt0337563,tt0478970,tt0988595
# 721        actor,soundtrack,producer  tt2278388,tt0145487,tt5649144,tt0189998
# 1396                 writer,producer  tt1179034,tt0120107,tt2172934,tt5369352
# 2737        producer,director,writer  tt0107554,tt1037705,tt0112819,tt0120681
# 2801           actor,producer,writer  tt0313443,tt0106057,tt2528814,tt0250687
# ...                              ...                                      ...
# 2380097                        actor  tt4420924,tt6554976,tt0135790,tt4420842
# 2380163                          NaN                      tt9067762,tt9356320
# 2380241     director,producer,writer  tt1124396,tt1728245,tt0105812,tt0303361
# 2380376                          NaN                                      NaN
# 2380402      actor,producer,director  tt0111512,tt0325655,tt0338564,tt0144029
#
#         directors_y   writers_y  ordering_y         category         job  \
# 342       nm0339460   nm0339460           4          actress         NaN
# 721       nm0000353   nm0000353           3            actor         NaN
# 1396      nm0367867   nm0367867           6           writer  screenplay
# 2737      nm0400441   nm0400441           5         director         NaN
# 2801      nm0001002   nm0001002           1            actor         NaN
# ...             ...         ...         ...              ...         ...
# 2380097   nm1110828   nm1110828           2            actor         NaN
# 2380163  nm10162112  nm10162112           8  cinematographer         NaN
# 2380241   nm0049592   nm0049592           5         director         NaN
# 2380376  nm10425794  nm10425794           1            actor         NaN
# 2380402   nm0874676   nm0874676           8            actor         NaN
#
#                  characters  averagerating  numvotes
# 342               ["Karen"]            7.0    539338
# 721         ["Tars Tarkas"]            6.6    241792
# 1396                    NaN            6.5    107079
# 2737                    NaN            6.2     71704
# 2801     ["Randy Simpkins"]            6.0       504
# ...                     ...            ...       ...
# 2380097           ["Oskar"]            5.9        43
# 2380163                 NaN            7.3         6
# 2380241                 NaN            4.0        99
# 2380376                 NaN            6.0        16
# 2380402                 NaN            6.0         6
#
# [17386 rows x 28 columns]

# %% [markdown]
# # Top 10 Directors by Top 10 Regions

# %% [markdown]
# # Problem: when filtering based on top_10_regions the director can/will have multiple regions under a single movies. this will effect the overall results

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_directors = final_merge[(final_merge['category'] == 'director') &\
                            (final_merge['region'].isin(top_10_regions))&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_directors_name = all_directors['primary_name'].value_counts()
#filtering director names that appear more than 3 times
all_directors_name_greater_2 = all_directors_name.values >= 3
#filtered names list vs geart than 3 list
the_directors_name = all_directors_name[all_directors_name_greater_2]


x = final_merge[(final_merge['primary_name'].isin(the_directors_name.index)) & (final_merge['is_original_title'] == 1)]

top_10_directors_region = x.groupby('primary_name')['averagerating'].mean().sort_values(ascending = False)

top_10_directors_region
# Out:
# Series([], Name: averagerating, dtype: float64)

# %% [markdown]
# # Top 10 Directors

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_foreign_directors = final_merge[(final_merge['category'] == 'director') &\
                           (final_merge['numvotes'] >= 5000) &\
                            (final_merge['region'].notna())&\
                           (final_merge['region'] != 'US')&\
                            (final_merge['runtime_minutes'] >= 40)]
filter_titles = all_directors.drop_duplicates('title')
primary_title = filter_titles.drop_duplicates('primary_title')
foreign_directors = primary_title['primary_name'].value_counts()
foreign_directors_3 = foreign_directors.values>=3
foreign_directors_filtered = all_foreign_directors[foreign_directors_3]
foreign_directors_filtered
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-0d83ba70c1c5> in <module>
#       9 foreign_directors = primary_title['primary_name'].value_counts()
#      10 foreign_directors_3 = foreign_directors.values>=3
# ---> 11 foreign_directors_filtered = all_foreign_directors[foreign_directors_3]
#      12 foreign_directors_filtered
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2937             )
#    2938         elif len(key) != len(self.index):
# -> 2939             raise ValueError(
#    2940                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2941             )
#
# ValueError: Item wrong length 0 instead of 69694.

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_directors = final_merge[(final_merge['category'] == 'director') &\
                            (final_merge['is_original_title'] == 1)&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_directors_name = all_directors['primary_name'].value_counts()
#filtering director names that appear more than 3 times
all_directors_name_greater_2 = all_directors_name.values >= 3
#filtered names list vs geart than 3 list
the_directors_name = all_directors_name[all_directors_name_greater_2]


x = final_merge[(final_merge['primary_name'].isin(the_directors_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
y = x.groupby('primary_name')['averagerating'].mean().sort_values(ascending = False)

top_10_directors = y[:10]
maybe = pd.DataFrame(top_10_directors).reset_index()
maybe

# %% [markdown]
# # Top 10 Writers

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_writers = final_merge[(final_merge['category'] == 'actor') &\
                            (final_merge['is_original_title'] == 1)&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_writers_name = all_writers['primary_name'].value_counts()
#filtering director names that appear more than 3 times
all_writers_name_greater_2 = all_writers_name.values >= 3
#filtered names list vs geart than 3 list
the_writers_name = all_writers_name[all_writers_name_greater_2]

x = final_merge[(final_merge['primary_name'].isin(the_writers_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
y = x.groupby('primary_name')['averagerating'].mean().sort_values(ascending = False)

top_10_writers = y[:10]
top_10_writers

# %% [markdown]
# # Top 10 Actors

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_actors = final_merge[(final_merge['category'] == 'actor') &\
                            (final_merge['is_original_title'] == 1)&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_actors_name = all_actors['primary_name'].value_counts()
#filtering director names that appear more than 3 times
all_actors_name_greater_2 = all_actors_name.values >= 3
#filtered names list vs geart than 3 list
the_actors_name = all_actors_name[all_actors_name_greater_2]

x = final_merge[(final_merge['primary_name'].isin(the_actors_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
y = x.groupby('primary_name')['averagerating'].mean().sort_values(ascending = False)

top_10_actors = y[:10]
top_10_actors

# %% [markdown]
# # Top 10 Actress

# %%
#all directors appearing in original title movies with a total number of votes greater than 5000
all_actress = final_merge[(final_merge['category'] == 'actress') &\
                            (final_merge['is_original_title'] == 1)&\
                           (final_merge['numvotes'] >= 5000)]
#total movies directors have appeared in 
all_actress_name = all_actress['primary_name'].value_counts()
#filtering director names that appear more than 3 times
all_actress_name_greater_2 = all_actress_name.values >= 3
#filtered names list vs geart than 3 list
the_actress_name = all_actress_name[all_actress_name_greater_2]


x = final_merge[(final_merge['primary_name'].isin(the_actress_name.index)) & (final_merge['is_original_title'] == 1)]
x.drop(['region'], 1, inplace = True)
y = x.groupby('primary_name')['averagerating'].mean().sort_values(ascending = False)

top_10_actress = y[:10]
top_10_actress

# %% [markdown]
# # Correlations?

# %%
avg_rating = final_merge.groupby('averagerating').mean()
avg_rating.drop(['ordering_x', 'start_year', 'birth_year'], 1, inplace=True)
avg_rating.reset_index(inplace=True)
plt.scatter(avg_rating['averagerating'], avg_rating['numvotes']);

# %%
avg_rating = final_merge.groupby('averagerating').mean()
avg_rating.drop(['ordering_x', 'start_year', 'birth_year'], 1, inplace=True)
avg_rating.reset_index(inplace=True)
plt.scatter(avg_rating['averagerating'], avg_rating['runtime_minutes']);

# %%
avg_rating = final_merge.groupby('averagerating').mean()
avg_rating.drop(['ordering_x', 'start_year', 'birth_year'], 1, inplace=True)
avg_rating.reset_index(inplace=True)
plt.scatter(avg_rating['runtime_minutes'], avg_rating['numvotes']);

# %%
final_merge['numvotes'].mean()

# %%
total_votes_30000 = final_merge[(final_merge['numvotes'] >= 30000)]

# %%
avg_rating = total_votes_30000.groupby('averagerating').mean()
avg_rating.reset_index(inplace=True)

# %%
avg_rating.drop(['ordering_x', 'is_original_title', 'birth_year'], 1, inplace=True)

# %%
avg_rating.corr()

# %%
final_merge['category']

# %%
data = [['movie1', '5', 'A', 'A'], ['movie2', '6', 'B', 'B'], ['movie3', '3', 'B', 'B']]
df = pd.DataFrame(data, columns = ['title', 'rating', 'nconst'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1683         blocks = form_blocks(arrays, names, axes)
# -> 1684         mgr = BlockManager(blocks, axes)
#    1685         mgr._consolidate_inplace()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     325             if block.shape[1:] != mgr_shape[1:]:
# --> 326                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     327         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (5, 1), indices imply (1, 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-34c1a58e5c05> in <module>
# ----> 1 df = pd.DataFrame({'A':['X', '1', '2', '3', 'X']}, {'Z':['B', '1', '2', '3', 'Z']})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1686         return mgr
#    1687     except ValueError as e:
# -> 1688         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1689
#    1690
#
# ValueError: Shape of passed values is (5, 1), indices imply (1, 1)

# %%
df
# Out:
#    0
# B  A
# 1  1
# 2  2
# 3  3
# B  A
